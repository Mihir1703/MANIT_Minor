# %% [markdown]
# # Multimodal Single-Cell Integration: Creating a Sparse Matrix Dataset

# %%
# !conda install pytables -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# !dir /s "Dataset"
# Out:
#  Volume in drive F is New Volume
#  Volume Serial Number is 92F6-A0F6
#
#  Directory of F:\Minor Project\Dataset
#
# 19-12-2022  03:01    <DIR>          .
# 19-12-2022  03:01    <DIR>          ..
# 07-09-2022  19:37     2,418,406,934 evaluation_ids.csv
# 07-09-2022  19:40         9,770,334 metadata.csv
# 07-09-2022  19:40           234,920 metadata_cite_day_2_donor_27678.csv
# 07-09-2022  19:40       843,563,244 sample_submission.csv
# 19-12-2022  18:16            10,048 test_cite_inputs.h5
# 07-09-2022  19:45       307,964,530 test_cite_inputs_day_2_donor_27678.h5
# 07-09-2022  19:46     6,473,530,657 test_multi_inputs.h5
# 07-09-2022  20:03     2,498,128,492 train_cite_inputs.h5
# 07-09-2022  20:10        38,539,123 train_cite_targets.h5
# 07-09-2022  20:10    11,334,840,656 train_multi_inputs.h5
# 07-09-2022  20:38     3,215,261,538 train_multi_targets.h5
#               11 File(s) 27,140,250,476 bytes
#
#      Total Files Listed:
#               11 File(s) 27,140,250,476 bytes
#                2 Dir(s)  115,220,365,312 bytes free

# %%
import pandas as pd
import numpy as np
import scipy.sparse
# Out:
# E:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import numpy as np
import h5py

arr = np.random.randn(1000)
 
# creating a file
with h5py.File('Dataset/test_cite_inputs.h5', 'w') as f:
    dset = f.create_dataset("default", data = arr)
    
print(dset)
# Out:
# <Closed HDF5 dataset>

# %% [markdown]
# # Conversion Functions

# %%
def convert_to_parquet(filename, out_filename):
    df = pd.read_csv(filename)
    df.to_parquet(out_filename + ".parquet")

# %%
import pandas as pd
from scipy import sparse
import numpy as np
import pyarrow
def convert_h5_to_sparse_csr(filename, out_filename, chunksize=2500):
    start = 0
    total_rows = 0

    sparse_chunks_data_list = []
    chunks_index_list = []
    columns_name = None
    while True:
        df_chunk = pd.read_hdf(filename, start=start, stop=start+chunksize)
        if len(df_chunk) == 0:
            break
        chunk_data_as_sparse = scipy.sparse.csr_matrix(df_chunk.to_numpy())
        sparse_chunks_data_list.append(chunk_data_as_sparse)
        chunks_index_list.append(df_chunk.index.to_numpy())

        if columns_name is None:
            columns_name = df_chunk.columns.to_numpy()
        else:
            assert np.all(columns_name == df_chunk.columns.to_numpy())

        total_rows += len(df_chunk)
        print(total_rows)
        if len(df_chunk) < chunksize: 
            del df_chunk
            break
        del df_chunk
        start += chunksize
        
    all_data_sparse = scipy.sparse.vstack(sparse_chunks_data_list)
    del sparse_chunks_data_list
    
    all_indices = np.hstack(chunks_index_list)
    
    scipy.sparse.save_npz(out_filename+"_values.sparse", all_data_sparse)
    np.savez(out_filename+"_idxcol.npz", index=all_indices, columns =columns_name)

# %%
import os

directory = 'Dataset'

for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        split_tup = os.path.splitext(f)
        if(split_tup[1]=='.h5'):
            split_tup[0].replace('Dataset/', ' ')
            print(split_tup[0])
            convert_h5_to_sparse_csr(f,f"New/{split_tup[0]}")
            
        if(split_tup[1]=='.csv'):
            convert_to_parquet(f, f"New/{split_tup[0]}")

def run_sparse():
    print("train_multi_targets.h5")
    convert_h5_to_sparse_csr("Dataset/train_multi_targets.h5", "New/Dataset/train_multi_targets")
    print("train_multi_inputs.h5")
    convert_h5_to_sparse_csr("Dataset/train_multi_inputs.h5", "New/Dataset/train_multi_inputs")
    print("train_cite_targets.h5")
    convert_h5_to_sparse_csr("Dataset/train_cite_targets.h5", "New/Dataset/train_cite_targets")
    print("train_cite_inputs.h5")
    convert_h5_to_sparse_csr("Dataset/train_cite_inputs.h5", "New/Dataset/train_cite_inputs")
    print("test_multi_inputs.h5")
    convert_h5_to_sparse_csr("Dataset/test_multi_inputs.h5", "New/Dataset/test_multi_inputs")
# Out:
# train_multi_targets.h5
# 2500
# 5000
# 7500
# 10000
# 12500
# 15000
# 17500
# 20000
# 22500
# 25000
# 27500
# 30000
# 32500
# 35000
# 37500
# 40000
# 42500
# 45000
# 47500
# 50000
# 52500
# 55000
# 57500
# 60000
# 62500
# 65000
# 67500
# 70000
# 72500
# 75000
# 77500
# 80000
# 82500
# 85000
# 87500
# 90000
# 92500
# 95000
# 97500
# 100000
# 102500
# 105000
# 105942
# train_multi_inputs.h5
# 2500
# 5000
# 7500
# 10000
# 12500
# 15000
# 17500
# 20000
# 22500
# 25000
# 27500
# 30000
# 32500
# 35000
# 37500
# 40000
# 42500
# 45000
# 47500
# 50000
# 52500
# 55000
# 57500
# 60000
# 62500
# 65000
# 67500
# 70000
# 72500
# 75000
# 77500
# 80000
# 82500
# 85000
# 87500
# 90000
# 92500
# 95000
# 97500
# 100000
# 102500
# 105000
# 105942
# train_cite_targets.h5
# 2500
# 5000
# 7500
# 10000
# 12500
# 15000
# 17500
# 20000
# 22500
# 25000
# 27500
# 30000
# 32500
# 35000
# 37500
# 40000
# 42500
# 45000
# 47500
# 50000
# 52500
# 55000
# 57500
# 60000
# 62500
# 65000
# 67500
# 70000
# 70988
# train_cite_inputs.h5
# 2500
# 5000
# 7500
# 10000
# 12500
# 15000
# 17500
# 20000
# 22500
# 25000
# 27500
# 30000
# 32500
# 35000
# 37500
# 40000
# 42500
# 45000
# 47500
# 50000
# 52500
# 55000
# 57500
# 60000
# 62500
# 65000
# 67500
# 70000
# 70988
# test_multi_inputs.h5
# 2500
# 5000
# 7500
# 10000
# 12500
# 15000
# 17500
# 20000
# 22500
# 25000
# 27500
# 30000
# 32500
# 35000
# 37500
# 40000
# 42500
# 45000
# 47500
# 50000
# 52500
# 55000
# 55935
# test_cite_inputs.h5
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_580/1284429068.py in <module>
#      26 convert_h5_to_sparse_csr("Dataset/test_multi_inputs.h5", "New/Dataset/test_multi_inputs")
#      27 print("test_cite_inputs.h5")
# ---> 28 convert_h5_to_sparse_csr("Datatset/test_cite_inputs.h5", "New/Dataset/test_cite_inputs")
#
# ~\AppData\Local\Temp/ipykernel_580/4221517680.py in convert_h5_to_sparse_csr(filename, out_filename, chunksize)
#      11     columns_name = None
#      12     while True:
# ---> 13         df_chunk = pd.read_hdf(filename, start=start, stop=start+chunksize)
#      14         if len(df_chunk) == 0:
#      15             break
#
# E:\Anaconda\lib\site-packages\pandas\io\pytables.py in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     425
#     426         if not exists:
# --> 427             raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     428
#     429         store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#
# FileNotFoundError: File Datatset/test_cite_inputs.h5 does not exist

# %%
# print("test_cite_inputs.h5")
# convert_h5_to_sparse_csr("Dataset/test_cite_inputs.h5", "New/Dataset/test_cite_inputs")

# %%
conda install -c conda-forge pyarrow
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: E:\Anaconda
#
#   added / updated specs:
#     - pyarrow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     arrow-cpp-8.0.0            |   py39hbd6f097_0         6.2 MB
#     aws-c-common-0.4.57        |       ha925a31_1         147 KB
#     aws-c-event-stream-0.1.6   |       hd77b12b_5          26 KB
#     aws-checksums-0.1.9        |       ha925a31_0          50 KB
#     aws-sdk-cpp-1.8.185        |       hd77b12b_0         2.5 MB
#     blosc-1.21.0               |       h19a0ad4_1         145 KB
#     boost-cpp-1.78.0           |       h5b4e17d_0        17.0 MB  conda-forge
#     c-ares-1.18.1              |       h8ffe710_0         114 KB  conda-forge
#     ca-certificates-2022.12.7  |       h5b45459_0         143 KB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     conda-22.11.1              |   py39hcbf5309_1         908 KB  conda-forge
#     gflags-2.2.2               |    ha925a31_1004          80 KB  conda-forge
#     glog-0.6.0                 |       h4797de2_0          95 KB  conda-forge
#     imagecodecs-2021.8.26      |   py39hc0a7faf_1         6.0 MB
#     libarchive-3.6.1           |       hebabd0d_0         1.7 MB
#     libthrift-0.15.0           |       h636ae23_0         872 KB  conda-forge
#     pyarrow-8.0.0              |   py39h953b917_0         2.1 MB
#     re2-2022.04.01             |       h0e60522_0         472 KB  conda-forge
#     utf8proc-2.6.1             |       h2bbff1b_0         312 KB
#     zstd-1.5.2                 |       h19a0ad4_0         509 KB
#     ------------------------------------------------------------
#                                            Total:        39.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   arrow-cpp          pkgs/main/win-64::arrow-cpp-8.0.0-py39hbd6f097_0
#   aws-c-common       pkgs/main/win-64::aws-c-common-0.4.57-ha925a31_1
#   aws-c-event-stream pkgs/main/win-64::aws-c-event-stream-0.1.6-hd77b12b_5
#   aws-checksums      pkgs/main/win-64::aws-checksums-0.1.9-ha925a31_0
#   aws-sdk-cpp        pkgs/main/win-64::aws-sdk-cpp-1.8.185-hd77b12b_0
#   boost-cpp          conda-forge/win-64::boost-cpp-1.78.0-h5b4e17d_0
#   c-ares             conda-forge/win-64::c-ares-1.18.1-h8ffe710_0
#   gflags             conda-forge/win-64::gflags-2.2.2-ha925a31_1004
#   glog               conda-forge/win-64::glog-0.6.0-h4797de2_0
#   libthrift          conda-forge/win-64::libthrift-0.15.0-h636ae23_0
#   pyarrow            pkgs/main/win-64::pyarrow-8.0.0-py39h953b917_0
#   re2                conda-forge/win-64::re2-2022.04.01-h0e60522_0
#   utf8proc           pkgs/main/win-64::utf8proc-2.6.1-h2bbff1b_0
#
# The following packages will be UPDATED:
#
#   blosc                                   1.21.0-h19a0ad4_0 --> 1.21.0-h19a0ad4_1
#   ca-certificates    pkgs/main::ca-certificates-2022.10.11~ --> conda-forge::ca-certificates-2022.12.7-h5b45459_0
#   certifi            pkgs/main/win-64::certifi-2022.9.24-p~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   imagecodecs                      2021.8.26-py39ha1f97ea_0 --> 2021.8.26-py39hc0a7faf_1
#   libarchive                               3.4.2-h5e25573_0 --> 3.6.1-hebabd0d_0
#   zstd                                     1.4.9-h19a0ad4_0 --> 1.5.2-h19a0ad4_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-22.11.1-py39haa95532~ --> conda-forge::conda-22.11.1-py39hcbf5309_1
#
#
#
# Downloading and Extracting Packages
#
# zstd-1.5.2           | 509 KB    |            |   0%
#
# pyarrow-8.0.0        | 2.1 MB    |            |   0%
#
#
# aws-c-common-0.4.57  | 147 KB    |            |   0%
#
#
#
# gflags-2.2.2         | 80 KB     |            |   0%
#
#
#
#
# libthrift-0.15.0     | 872 KB    |            |   0%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    |            |   0%
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    |            |   0%
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    |            |   0%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   |            |   0%
#
#
#
#
#
#
#
#
#
# blosc-1.21.0         | 145 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# aws-checksums-0.1.9  | 50 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 143 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-22.11.1        | 908 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# utf8proc-2.6.1       | 312 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.8.185  | 2.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-event-stream-0 | 26 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glog-0.6.0           | 95 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arrow-cpp-8.0.0      | 6.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# zstd-1.5.2           | 509 KB    | 3          |   3%
#
# pyarrow-8.0.0        | 2.1 MB    |            |   1%
#
#
#
# gflags-2.2.2         | 80 KB     | #9         |  20%
# zstd-1.5.2           | 509 KB    | #8         |  19%
#
# pyarrow-8.0.0        | 2.1 MB    | 4          |   4%
#
#
#
# gflags-2.2.2         | 80 KB     | #########9 | 100%
# zstd-1.5.2           | 509 KB    | ###7       |  38%
#
#
#
#
# libthrift-0.15.0     | 872 KB    | 1          |   2%
#
#
#
# gflags-2.2.2         | 80 KB     | ########## | 100%
#
#
# aws-c-common-0.4.57  | 147 KB    | #          |  11%
#
# pyarrow-8.0.0        | 2.1 MB    | #          |  10%
#
#
#
#
# libthrift-0.15.0     | 872 KB    | ##5        |  26%
# zstd-1.5.2           | 509 KB    | ######2    |  63%
#
# pyarrow-8.0.0        | 2.1 MB    | #5         |  15%
#
#
# aws-c-common-0.4.57  | 147 KB    | #######6   |  76%
#
#
# aws-c-common-0.4.57  | 147 KB    | ########## | 100%
# zstd-1.5.2           | 509 KB    | #########7 |  97%
#
#
#
#
# libthrift-0.15.0     | 872 KB    | #####6     |  57%
#
# pyarrow-8.0.0        | 2.1 MB    | ##3        |  23%
# zstd-1.5.2           | 509 KB    | ########## | 100%
#
# pyarrow-8.0.0        | 2.1 MB    | ###        |  31%
#
#
#
#
# libthrift-0.15.0     | 872 KB    | ########## | 100%
#
#
#
#
# libthrift-0.15.0     | 872 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   |            |   0%
#
#
#
#
#
#
#
#
#
# blosc-1.21.0         | 145 KB    | #1         |  11%
#
# pyarrow-8.0.0        | 2.1 MB    | ########## | 100%
#
# pyarrow-8.0.0        | 2.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# blosc-1.21.0         | 145 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    |            |   0%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | 8          |   9%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | 8          |   8%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | #1         |  12%
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    | #          |  11%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | #6         |  16%
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | #1         |  11%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    |            |   1%
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    | #########7 |  98%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | #9         |  19%
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    | ########## | 100%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | ##5        |  25%
#
#
#
#
#
#
#
#
#
#
#
# aws-checksums-0.1.9  | 50 KB     | ###1       |  32%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    | #          |  10%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | ##5        |  25%
#
#
#
#
#
#
#
#
#
#
#
# aws-checksums-0.1.9  | 50 KB     | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# aws-checksums-0.1.9  | 50 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | ###1       |  31%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | ###1       |  32%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    | #8         |  18%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | ###7       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 143 KB    | #1         |  11%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    | ##3        |  23%
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 143 KB    | ########9  |  89%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | ###9       |  39%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | ####1      |  42%
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    | #6         |  17%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    | ###9       |  40%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 143 KB    | ########## | 100%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    | ####6      |  46%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-22.11.1        | 908 KB    | 1          |   2%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    | #######6   |  77%
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    | ##7        |  27%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | #####8     |  59%
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-22.11.1        | 908 KB    | #          |  11%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# utf8proc-2.6.1       | 312 KB    | 5          |   5%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    | ########## | 100%
#
#
#
#
#
# libarchive-3.6.1     | 1.7 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | ######3    |  63%
#
#
# Note: you may need to restart the kernel to use updated packages.
# utf8proc-2.6.1       | 312 KB    | ####6      |  46%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | ######7    |  68%
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    | #######4   |  75%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | #######1   |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# utf8proc-2.6.1       | 312 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-22.11.1        | 908 KB    | ##1        |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.8.185  | 2.5 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | ########   |  80%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | #######1   |  72%
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.8.185  | 2.5 MB    | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-22.11.1        | 908 KB    | ###8       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.8.185  | 2.5 MB    | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-22.11.1        | 908 KB    | ####5      |  46%
#
#
#
#
#
#
#
# re2-2022.04.01       | 472 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | ########6  |  86%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | ########   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.8.185  | 2.5 MB    | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-22.11.1        | 908 KB    | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-event-stream-0 | 26 KB     | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.8.185  | 2.5 MB    | #####6     |  56%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-22.11.1        | 908 KB    | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
# imagecodecs-2021.8.2 | 6.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-event-stream-0 | 26 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-event-stream-0 | 26 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.8.185  | 2.5 MB    | ########3  |  83%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.8.185  | 2.5 MB    | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-22.11.1        | 908 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glog-0.6.0           | 95 KB     | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-sdk-cpp-1.8.185  | 2.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# glog-0.6.0           | 95 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arrow-cpp-8.0.0      | 6.2 MB    |            |   0%
#
#
#
#
#
#
#
#
# boost-cpp-1.78.0     | 17.0 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arrow-cpp-8.0.0      | 6.2 MB    | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arrow-cpp-8.0.0      | 6.2 MB    | ####1      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arrow-cpp-8.0.0      | 6.2 MB    | ######7    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arrow-cpp-8.0.0      | 6.2 MB    | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arrow-cpp-8.0.0      | 6.2 MB    | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arrow-cpp-8.0.0      | 6.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# !dir /s "New/Dataset"
# Out:
#  Volume in drive F is New Volume
#  Volume Serial Number is 92F6-A0F6
#
#  Directory of F:\Minor Project\New\Dataset
#
# 19-12-2022  18:14    <DIR>          .
# 19-12-2022  18:14    <DIR>          ..
# 19-12-2022  18:14         3,910,641 metadata.parquet
# 19-12-2022  18:05                 0 train_multi_targets_values.sparse.npz
#                2 File(s)      3,910,641 bytes
#
#      Total Files Listed:
#                2 File(s)      3,910,641 bytes
#                2 Dir(s)  115,190,116,352 bytes free

# %%
convert_to_parquet("Dataset/metadata.csv", "New/Dataset/metadata")
convert_to_parquet("Dataset/evaluation_ids.csv", "New/Dataset/evaluation")
convert_to_parquet("Dataset/sample_submission.csv", "New/Dataset/sample_submission")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13632/3409477812.py in <module>
#       1 convert_to_parquet("Dataset/metadata.csv", "New/Dataset/metadata")
# ----> 2 convert_to_parquet("Dataset/evaluation_ids.csv", "New/Dataset/evaluation")
#       3 convert_to_parquet("Dataset/sample_submission.csv", "New/Dataset/sample_submission")
#
# ~\AppData\Local\Temp/ipykernel_13632/1102031318.py in convert_to_parquet(filename, out_filename)
#       1 def convert_to_parquet(filename, out_filename):
# ----> 2     df = pd.read_csv(filename)
#       3     df.to_parquet(out_filename + ".parquet")
#
# E:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# E:\Anaconda\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# E:\Anaconda\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# E:\Anaconda\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# E:\Anaconda\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# E:\Anaconda\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.
